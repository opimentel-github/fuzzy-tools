# %%
import sys
sys.path.append('../../') # or just install the module

# %%
import numpy as np

N = 50
class_names = ['a', 'b', 'c']
y_true = np.random.randint(0, len(class_names), size=(N))
obj_ids = [f'obj{k}' for k in range(0, len(y_true))]
y_pred_p = np.random.uniform(0, 1, size=(N, len(class_names)))
y_pred_p = y_pred_p/np.sum(y_pred_p, axis=1)[...,None]
print('y_true', y_true, y_true.shape)
print('y_pred_p', y_pred_p.shape)
# Out:
# y_true [0 2 0 2 0 2 0 2 1 1 2 2 2 1 1 1 0 2 0 2 0 0 1 1 0 2 0 1 2 1 2 0 1 2 2 1 0
#  1 0 1 2 1 2 0 2 2 0 0 2 0] (50,)
# y_pred_p (50, 3)

# %%
# %load_ext autoreload
# %autoreload 2
from fuzzytools.datascience import missclassifications
import matplotlib.pyplot as plt

missclassifications.plot_missclassifications(y_pred_p, y_true, class_names,
    obj_ids=obj_ids,
    pred_prob_th=.5, # None .5
    figsize=(10,8),
    verbose=1,
    )
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# k=0; c=a; txt=obj0 [c]
# k=1; c=a; txt=obj2 [b]
# k=3; c=a; txt=obj6 [c]
# k=4; c=a; txt=obj16 [b]
# k=5; c=a; txt=obj18 [b]
# k=7; c=a; txt=obj21 [c]
# k=8; c=a; txt=obj24 [c]
# k=9; c=a; txt=obj26 [c]
# k=10; c=a; txt=obj31 [b]
# k=11; c=a; txt=obj36 [b]
# k=12; c=a; txt=obj38 [b]
# k=13; c=a; txt=obj43 [c]
# k=15; c=a; txt=obj47 [b]
# k=16; c=a; txt=obj49 [c]
# k=0; c=b; txt=obj8 [c]
# k=2; c=b; txt=obj13 [a]
# k=3; c=b; txt=obj14 [a]
# k=5; c=b; txt=obj22 [c]
# k=8; c=b; txt=obj29 [a]
# k=9; c=b; txt=obj32 [a]
# k=11; c=b; txt=obj37 [c]
# k=12; c=b; txt=obj39 [a]
# k=1; c=c; txt=obj3 [b]
# k=2; c=c; txt=obj5 [a]
# k=5; c=c; txt=obj11 [a]
# k=7; c=c; txt=obj17 [b]
# k=8; c=c; txt=obj19 [b]
# k=11; c=c; txt=obj30 [b]
# k=12; c=c; txt=obj33 [b]
# k=13; c=c; txt=obj34 [b]
# k=14; c=c; txt=obj40 [b]
# k=16; c=c; txt=obj44 [b]
# k=17; c=c; txt=obj45 [b]
# k=18; c=c; txt=obj48 [a]
