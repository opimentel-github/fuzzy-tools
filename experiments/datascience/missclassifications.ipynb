# %%
import sys
sys.path.append('../../') # or just install the module

# %%
import numpy as np

N = 150
class_names = ['a', 'b', 'c']
y_true = np.random.randint(0, len(class_names), size=(N))
obj_ids = [f'obj{k}' for k in range(0, len(y_true))]
y_pred_p = np.random.uniform(0, 1, size=(N, len(class_names)))
y_pred_p = y_pred_p/np.sum(y_pred_p, axis=1)[...,None]
print('y_true', y_true, y_true.shape)
print('y_pred_p', y_pred_p.shape)
# Out:
# y_true [0 2 2 1 0 2 2 1 1 0 0 0 0 2 0 1 2 2 1 2 2 1 2 0 2 1 0 0 2 0 1 2 0 0 2 1 0
#  1 2 2 0 2 1 2 2 0 0 0 1 2 1 2 1 2 0 2 2 1 0 1 1 1 0 0 0 0 2 0 0 1 0 2 1 0
#  0 2 2 0 2 1 1 0 1 1 0 1 1 2 0 0 1 1 2 1 2 0 0 1 2 1 0 1 2 2 1 0 2 0 1 0 0
#  0 1 2 2 2 0 2 0 2 0 1 1 0 0 2 2 1 1 2 0 0 2 0 2 0 2 0 0 0 0 2 1 1 2 2 2 1
#  1 1] (150,)
# y_pred_p (150, 3)

# %%
# %load_ext autoreload
# %autoreload 2
from fuzzytools.datascience import missclassifications
import matplotlib.pyplot as plt

missclassifications.plot_missclassification_map(y_pred_p, y_true, class_names,
    obj_ids=obj_ids,
    pred_prob_th=.5, # None .5
    figsize=(10,8),
    verbose=1,
    )
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# k=1; c=a; obj_y_pred_p=0.647; txt=obj4 [c]
# k=3; c=a; obj_y_pred_p=0.530; txt=obj10 [c]
# k=6; c=a; obj_y_pred_p=0.710; txt=obj14 [c]
# k=14; c=a; obj_y_pred_p=0.627; txt=obj40 [c]
# k=15; c=a; obj_y_pred_p=0.655; txt=obj45 [b]
# k=19; c=a; obj_y_pred_p=0.524; txt=obj58 [c]
# k=28; c=a; obj_y_pred_p=0.608; txt=obj74 [c]
# k=30; c=a; obj_y_pred_p=0.522; txt=obj81 [b]
# k=34; c=a; obj_y_pred_p=0.758; txt=obj95 [b]
# k=36; c=a; obj_y_pred_p=0.548; txt=obj100 [b]
# k=37; c=a; obj_y_pred_p=0.573; txt=obj105 [b]
# k=42; c=a; obj_y_pred_p=0.718; txt=obj116 [c]
# k=44; c=a; obj_y_pred_p=0.551; txt=obj120 [b]
# k=47; c=a; obj_y_pred_p=0.554; txt=obj130 [c]
# k=49; c=a; obj_y_pred_p=0.522; txt=obj133 [c]
# k=51; c=a; obj_y_pred_p=0.577; txt=obj137 [c]
# k=54; c=a; obj_y_pred_p=0.505; txt=obj140 [c]
# k=0; c=b; obj_y_pred_p=0.627; txt=obj3 [a]
# k=1; c=b; obj_y_pred_p=0.623; txt=obj7 [c]
# k=4; c=b; obj_y_pred_p=0.534; txt=obj18 [c]
# k=6; c=b; obj_y_pred_p=0.805; txt=obj25 [a]
# k=7; c=b; obj_y_pred_p=0.650; txt=obj30 [c]
# k=12; c=b; obj_y_pred_p=0.672; txt=obj50 [a]
# k=14; c=b; obj_y_pred_p=0.688; txt=obj57 [a]
# k=21; c=b; obj_y_pred_p=0.586; txt=obj80 [c]
# k=22; c=b; obj_y_pred_p=0.582; txt=obj82 [c]
# k=23; c=b; obj_y_pred_p=0.553; txt=obj83 [a]
# k=24; c=b; obj_y_pred_p=0.741; txt=obj85 [a]
# k=25; c=b; obj_y_pred_p=0.964; txt=obj86 [a]
# k=30; c=b; obj_y_pred_p=0.556; txt=obj99 [a]
# k=34; c=b; obj_y_pred_p=0.611; txt=obj112 [c]
# k=38; c=b; obj_y_pred_p=0.656; txt=obj128 [a]
# k=39; c=b; obj_y_pred_p=0.552; txt=obj142 [a]
# k=41; c=b; obj_y_pred_p=0.749; txt=obj147 [a]
# k=0; c=c; obj_y_pred_p=0.507; txt=obj1 [a]
# k=1; c=c; obj_y_pred_p=0.570; txt=obj2 [b]
# k=2; c=c; obj_y_pred_p=0.508; txt=obj5 [b]
# k=4; c=c; obj_y_pred_p=0.525; txt=obj13 [b]
# k=10; c=c; obj_y_pred_p=0.653; txt=obj24 [b]
# k=11; c=c; obj_y_pred_p=0.614; txt=obj28 [a]
# k=12; c=c; obj_y_pred_p=0.758; txt=obj31 [a]
# k=15; c=c; obj_y_pred_p=0.692; txt=obj39 [a]
# k=16; c=c; obj_y_pred_p=0.670; txt=obj41 [b]
# k=20; c=c; obj_y_pred_p=0.569; txt=obj51 [a]
# k=22; c=c; obj_y_pred_p=0.803; txt=obj55 [a]
# k=24; c=c; obj_y_pred_p=0.513; txt=obj66 [b]
# k=26; c=c; obj_y_pred_p=0.515; txt=obj75 [b]
# k=33; c=c; obj_y_pred_p=0.670; txt=obj102 [b]
# k=39; c=c; obj_y_pred_p=0.700; txt=obj117 [a]
# k=43; c=c; obj_y_pred_p=0.654; txt=obj129 [b]
# k=47; c=c; obj_y_pred_p=0.645; txt=obj141 [b]
# k=49; c=c; obj_y_pred_p=0.956; txt=obj145 [a]
