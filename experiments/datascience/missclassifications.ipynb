# %%
import sys
sys.path.append('../../') # or just install the module

# %%
import numpy as np

N = 50
class_names = ['a', 'b', 'c']
y_true = np.random.randint(0, len(class_names), size=(N))
obj_ids = [f'obj{k}' for k in range(0, len(y_true))]
y_pred_p = np.random.uniform(0, 1, size=(N, len(class_names)))
y_pred_p = y_pred_p/np.sum(y_pred_p, axis=1)[...,None]
print('y_true', y_true, y_true.shape)
print('y_pred_p', y_pred_p.shape)
# Out:
# y_true [2 0 2 0 2 0 2 0 1 2 1 1 0 1 0 2 1 1 2 0 2 1 0 2 2 1 0 1 0 2 2 1 0 0 1 2 2
#  0 0 0 2 1 1 0 2 0 0 2 1 2] (50,)
# y_pred_p (50, 3)

# %%
# %load_ext autoreload
# %autoreload 2
from fuzzytools.datascience import missclassifications
import matplotlib.pyplot as plt

missclassifications.plot_missclassification_map(y_pred_p, y_true, class_names,
    obj_ids=obj_ids,
    pred_prob_th=.5, # None .5
    figsize=(10,8),
    verbose=1,
    )
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# k=8; c=a; txt=obj26 [c]
# k=9; c=a; txt=obj28 [b]
# k=13; c=a; txt=obj38 [b]
# k=15; c=a; txt=obj43 [b]
# k=16; c=a; txt=obj45 [c]
# k=17; c=a; txt=obj46 [b]
# k=0; c=b; txt=obj8 [a]
# k=3; c=b; txt=obj13 [a]
# k=4; c=b; txt=obj16 [c]
# k=5; c=b; txt=obj17 [c]
# k=7; c=b; txt=obj25 [a]
# k=8; c=b; txt=obj27 [a]
# k=0; c=c; txt=obj0 [a]
# k=3; c=c; txt=obj6 [b]
# k=4; c=c; txt=obj9 [a]
# k=6; c=c; txt=obj18 [b]
# k=7; c=c; txt=obj20 [b]
# k=8; c=c; txt=obj23 [a]
# k=9; c=c; txt=obj24 [b]
# k=11; c=c; txt=obj30 [a]
# k=12; c=c; txt=obj35 [a]
# k=16; c=c; txt=obj47 [b]
# k=17; c=c; txt=obj49 [a]
