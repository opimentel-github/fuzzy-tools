# %%
import sys
sys.path.append('..')

# %%
from mnist import MNIST
import numpy as np

mndata = MNIST('./mnist')
raw_x, raw_y = mndata.load_training()
raw_x = np.array(raw_x).astype(np.float32)/255.0
raw_y = np.array(raw_y)
CLASS_NAMES = np.arange(0,10)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

ind = 55
print(raw_y[ind])
img = np.reshape(raw_x[ind,:],(28,28))
plt.imshow(img)
# Out:
# 8

# %%
from utils import print_np_ram

print('raw_x',raw_x.shape,raw_x.dtype)
print_np_ram('raw_x',raw_x)

print('raw_y',raw_y.shape,raw_y.dtype)
print_np_ram('raw_y',raw_y)
# Out:
# raw_x (60000, 784) float32
# raw_x: 188.16 RAM (Mbs)
# raw_y (60000,) uint8
# raw_y: 0.06 RAM (Mbs)

# %%
from sklearn.model_selection import train_test_split

random_state = 0
x_train, x_test, y_train, y_test = train_test_split(raw_x,raw_y,test_size=0.3, random_state=random_state)
print('x_train',x_train.shape)
print('x_test',x_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
# Out:
# x_train (42000, 784)
# x_test (18000, 784)
# y_train (42000,)
# y_test (18000,)

# %%
# %load_ext autoreload
# %autoreload 2

import tinyFlame
from tinyFlame.handler import ModelHandler, SAVE_OPTIONS, TrainHandler
from tinyFlame.losses import cross_entropy
from tinyFlame.metrics import accuracy, dummy_accuracy
from tinyFlame.models import SimpleMLP

def generate_model_name():
    num_features = len(feature_names)-1
    name = ''
    for i in range(num_features-1):
        name += feature_names[i]#+'.'
    name += feature_names[num_features-1]+'_'
    name += preproc+'_DROP01_'
    name += 'L'+str(latent_layers)
    name +='_U'+str(latent_dim)
    name += '_bi'*bi_lstm
    return name

batch_size = 50 # BATCH
epochs = 20 # 100

#model_name = generate_model_name()
model_name = 'nan'
input_dim = [x_train.shape[-1]]

output_dim = [len(CLASS_NAMES)]

model_parameters = {
'output_dim' : output_dim,
'epochs' : epochs,
'input_dim' : input_dim,
'hidden_units' : 200,
'hidden_layers' : 3, # 3
'drop_out' : 0.2,
'name' : model_name,
}
myModel = SimpleMLP(model_parameters)

train_parameters = {
'input_dim' : input_dim,
'epochs' : epochs,
'batch_size' : batch_size,
'data_path' : 'save',
'id' : 0,
}

print("output_dim:",model_parameters['output_dim'])
print("input_dim:",model_parameters['input_dim'])

myModel = ModelHandler(myModel, myModel.name, train_parameters)
myModel.build()
myModel.set_loss(cross_entropy)
myModel.set_metrics({'accuracy': accuracy,'dummy_accuracy': dummy_accuracy,})
#myModel.set_optimizer(optim.Adam(self.model.parameters(), lr=0.001))

load = 0
train = 1
debug = 0

save_mode = SAVE_OPTIONS.BEST_METRI_CFINAL
save_mode = SAVE_OPTIONS.BEST_LOSS_FINAL
patience = 2
myModel.set_train_handler(TrainHandler(save_mode, target_saved_metric=0, patience_epochs=patience))

if load:
    myModel.load_model()
if train:
    #myModel.fit((x_train,y_train),(x_train,y_train),debug=debug,save_mode=save_mode)
    myModel.fit((x_train,y_train),(x_test,y_test), debug=debug)
    #myModel.fit((x_train,y_train),(x_train,y_train), debug=debug)
# Out:
# output_dim: [10]
# input_dim: [784]
# ================================================================================
# ================================================================================
#
# Model name: nan
# ID: 0
# GPUs: 4
# Using: cuda:0 (GeForce GTX 1080 Ti)
# Model total parameters: 279610
# SimpleMLP(
#   (fc_in): Linear(in_features=784, out_features=200, bias=True)
#   (fc_h): ModuleList(
#     (0): Linear(in_features=200, out_features=200, bias=True)
#     (1): Linear(in_features=200, out_features=200, bias=True)
#     (2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (dropout): Dropout(p=0.2)
#   (fc_out): Linear(in_features=200, out_features=10, bias=True)
#   (softmax): Softmax()
# )
# ----------------------------------------------------------------------------------------------------
# Layer                   Kernel Shape         Output Shape         # Params (K)      # Mult-Adds (M)
# ====================================================================================================
# 0_Linear                  [784, 200]            [50, 200]               157.00                 0.16
# 1_Linear                  [200, 200]            [50, 200]                40.20                 0.04
# 2_Dropout                          -            [50, 200]                    -                    -
# 3_Linear                  [200, 200]            [50, 200]                40.20                 0.04
# 4_Dropout                          -            [50, 200]                    -                    -
# 5_Linear                  [200, 200]            [50, 200]                40.20                 0.04
# 6_Dropout                          -            [50, 200]                    -                    -
# 7_Linear                   [200, 10]             [50, 10]                 2.01                 0.00
# ====================================================================================================
# # Params:    279.61K
# # Mult-Adds: 0.28M
# ----------------------------------------------------------------------------------------------------
# > train_data_x: (42000, 784) float32
# > train_data_y: (42000,) uint8
# Using default optimizer...
# Save mode: best_loss_final
# ________________________________________________________________________________
# --------------------------------------------------------------------------------
# Epoch: 1/20 - id: 0 - Patience: 0/2
# Training mins: 0.0919
# Training Results - Avg loss: 0.124873  Avg accuracy: 0.9641  Avg dummy_accuracy: 0.0000  mins: 0.0254
# Validation Results - Avg loss: 0.151705  Avg accuracy: 0.9544  Avg dummy_accuracy: 0.0000  mins: 0.0155
# *** saving (best_loss_final): save/nan/id_0-epoch_1.tfes ***
# --------------------------------------------------------------------------------
# Epoch: 2/20 - id: 0 - Patience: 0/2
# Training mins: 0.0912
# Training Results - Avg loss: 0.093891  Avg accuracy: 0.9730  Avg dummy_accuracy: 0.0000  mins: 0.0399
# Validation Results - Avg loss: 0.129637  Avg accuracy: 0.9623  Avg dummy_accuracy: 0.0000  mins: 0.0095
# *** saving (best_loss_final): save/nan/id_0-epoch_2.tfes ***
# --------------------------------------------------------------------------------
# Epoch: 3/20 - id: 0 - Patience: 0/2
# Training mins: 0.0956
# Training Results - Avg loss: 0.067128  Avg accuracy: 0.9802  Avg dummy_accuracy: 0.0000  mins: 0.0294
# Validation Results - Avg loss: 0.124486  Avg accuracy: 0.9674  Avg dummy_accuracy: 0.0000  mins: 0.0158
# *** saving (best_loss_final): save/nan/id_0-epoch_3.tfes ***
# --------------------------------------------------------------------------------
# Epoch: 4/20 - id: 0 - Patience: 0/2
# Training mins: 0.0864
# Training Results - Avg loss: 0.053951  Avg accuracy: 0.9836  Avg dummy_accuracy: 0.0000  mins: 0.0410
# Validation Results - Avg loss: 0.109636  Avg accuracy: 0.9690  Avg dummy_accuracy: 0.0000  mins: 0.0082
# *** saving (best_loss_final): save/nan/id_0-epoch_4.tfes ***
# --------------------------------------------------------------------------------
# Epoch: 5/20 - id: 0 - Patience: 0/2
# Training mins: 0.0919
# Training Results - Avg loss: 0.036737  Avg accuracy: 0.9886  Avg dummy_accuracy: 0.0000  mins: 0.0267
# Validation Results - Avg loss: 0.100777  Avg accuracy: 0.9733  Avg dummy_accuracy: 0.0000  mins: 0.0136
# *** saving (best_loss_final): save/nan/id_0-epoch_5.tfes ***
# --------------------------------------------------------------------------------
# Epoch: 6/20 - id: 0 - Patience: 0/2
# Training mins: 0.0944
# Training Results - Avg loss: 0.036795  Avg accuracy: 0.9891  Avg dummy_accuracy: 0.0000  mins: 0.0393
# Validation Results - Avg loss: 0.104554  Avg accuracy: 0.9708  Avg dummy_accuracy: 0.0000  mins: 0.0105
# --------------------------------------------------------------------------------
# Epoch: 7/20 - id: 0 - Patience: 1/2
# Training mins: 0.0911
# Training Results - Avg loss: 0.034318  Avg accuracy: 0.9900  Avg dummy_accuracy: 0.0000  mins: 0.0291
# Validation Results - Avg loss: 0.118359  Avg accuracy: 0.9706  Avg dummy_accuracy: 0.0000  mins: 0.0164
# *** EARLY STOPPING - patience: 2 ***
# ________________________________________________________________________________
# End of training - total mins: 0.9634
# Time for best epoch (5) - total mins: 0.6824

# %%
myModel.show_train()
pass

# %%
ind = 55
print(raw_y[ind])
img = np.reshape(raw_x[ind,:],(28,28))
plt.imshow(img)
# Out:
# 8

# %%
'''
BENCHMARK MINS 20 epocas:
> PC i7 NO-GPU oscar: 3.0066

'''
# Out:
# '\nBENCHMARK MINS 20 epocas:\n> PC i7 NO-GPU oscar: 3.0066\n\n'

# %%
import importlib
import metricUtils
importlib.reload(metricUtils)
from metricUtils import get_cm_accuracy
from tinyFlame.predictions import *

pred_arr, true_arr = predict(myModel, x_test, y_test)
cm, accuracy = get_cm_accuracy(pred_arr, true_arr)

# %%
from metricUtils import plot_custom_confusion_matrix, ModelResults, ResultsID

results = ModelResults(myModel)
results.append(ResultsID(accuracy, cm))
#results.print()
plot_custom_confusion_matrix(cm, CLASS_NAMES)
pass
