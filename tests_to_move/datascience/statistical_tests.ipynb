8439625850340136, 0.9693877551020408, 0.9502551020408163, 0.8316326530612245, 0.8307823129251701, 0.9970313825275657, 0.9970313825275657, 0.9974554707379135, 0.9974554707379135, 0.9961832061068702, 0.9961832061068702, 0.996607294317218, 0.996607294317218, 0.9957591178965225, 0.994910941475827, 0.9927905004240882, 0.9927905004240882, 0.8618197278911566, 0.8579931972789115, 0.8979591836734694, 0.8839285714285715, 0.8681972789115646, 0.8660714285714286, 0.9468537414965987, 0.9664115646258504, 0.8928571428571429, 0.8826530612244898, 0.9166666666666667, 0.9562074829931972]
SLSN2 = [0.9221938775510204, 0.9158163265306123, 0.9047619047619048, 0.9090136054421769, 0.8881802721088435, 0.9328231292517006, 0.9081632653061225, 0.9064625850340136, 0.875, 0.9102891156462585, 0.9285714285714286, 0.9166666666666667, 0.9468537414965987, 0.9375, 0.9379251700680272, 0.9426020408163265, 0.9460034013605442, 0.9447278911564626, 0.9336734693877551, 0.9400510204081632, 0.9430272108843538, 0.9413265306122449, 0.9447278911564626, 0.9400510204081632, 0.9664970313825275, 0.9703138252756573, 0.9715860899067006, 0.9770992366412214, 0.9698897370653096, 0.9673452078032231, 0.9677692960135709, 0.9749787955894826, 0.9652247667514843, 0.9656488549618321, 0.9732824427480915, 0.9660729431721797, 0.9268707482993197, 0.9532312925170068, 0.9379251700680272, 0.9545068027210886, 0.9506802721088435, 0.9451530612244898, 0.9472789115646258, 0.9553571428571429, 0.9421768707482994, 0.9523809523809524, 0.9357993197278911, 0.9519557823129252, 0.9902459711620017, 0.991518235793045, 0.9910941475826972, 0.991518235793045, 0.9881255301102629, 0.9885496183206106, 0.9910941475826972, 0.9902459711620016, 0.9919423240033928, 0.9927905004240882, 0.991518235793045, 0.9910941475826972]

# %%
# %load_ext autoreload
# %autoreload 2
from fuzzytools.datascience import statistical_tests as statistical_tests
import numpy as np
from numpy import array
from fuzzytools.datascience.xerror import XError

values_dict = {
    'x1':XError(SLSN1),
    'x2':XError(SLSN2),
}
print(values_dict)
test = statistical_tests.permutationtest # ttest welchtest permutationtest
df = statistical_tests.gridtest_greater(values_dict, test,
    test_kwargs={'num_rounds':1e4},
    )
display(df)
# Out:
# {'x1': .944±.051, 'x2': .952±.029}
# {'<=0.001': '***', '<=0.01': '**', '<=0.05': '*', '<=0.1': '+', '<=inf': ''}
#                          x1; #samples=60 x2; #samples=60
# x1; #samples=60
# x2; #samples=60  $\Delta$=.008; $p$=.152

# %%
# %load_ext autoreload
# %autoreload 2
from fuzzytools.datascience import statistical_tests as statistical_tests
import numpy as np
from numpy import array
from fuzzytools.datascience.xerror import XError

n = 100
x1 = np.random.normal(0, 1, size=n)
x2 = np.random.normal(.1, 1, size=n)
values_dict = {
    'x1':XError(x1),
    'x2':XError(x2),
}
print(values_dict)
test = statistical_tests.permutationtest # ttest welchtest permutationtest
df = statistical_tests.gridtest_greater(values_dict, test,
    test_kwargs={'num_rounds':1e4},
    )
display(df)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'x1': -.171±1.037, 'x2': .077±.988}
# {'<=0.001': '***', '<=0.01': '**', '<=0.05': '*', '<=0.1': '+', '<=inf': ''}
#                  x1; #samples=100 x2; #samples=100
# x1; #samples=100
# x2; #samples=100   $\Delta$=.248*
