# %%
import sys
sys.path.append('../../') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from fuzzytools.matplotlib.animators import PlotAnimator
import fuzzytools.matplotlib.utils as utils
import numpy as np

plot_animation = PlotAnimator(f'../../temp/an.gif',
    video_duration=2, 
    save_frames=True,
    saved_frames_fext='pdf',
    init_offset=5,
    end_offset=2,
    )
figsize = (10,6)
dpi = 100
n = 1e3
for k in range(0,10):
    fig, ax = plt.subplots(1, 1, figsize=figsize, dpi=dpi)
    x = np.linspace(0, 100, int(n))
    ax.plot(x, np.sin(x*np.random.uniform()))
    ax.set_xticks([])
    ax.set_yticks([])
    title = f'k={k}'
    ax.set_title(title)
    plot_animation.append(fig)
    plt.show()
plot_animation.save()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-bb69bb9434e5> in <module>
#      26     #plot_animation.append(fig)
#      27     plt.show()
# ---> 28 plot_animation.save()
#
# ~/oscar/thesis/fuzzy-tools/fuzzytools/matplotlib/animators.py in save(self, reverse, clean_buffer)
#     105                                 self.reverse_frames()
#     106
# --> 107                         self.create_video_from_images()
#     108                         if clean_buffer:
#     109                                 self.clean()
#
# ~/oscar/thesis/fuzzy-tools/fuzzytools/matplotlib/animators.py in create_video_from_images(self)
#      53                 create_dir('/'.join(self.save_filedir.split('/')[:-1]))
#      54                 imgs = [frame for frame in self.frames]
# ---> 55                 frame_durations = [self.video_duration/len(self)]*len(self)
#      56
#      57                 if self.init_offset>0:
#
# ZeroDivisionError: division by zero
