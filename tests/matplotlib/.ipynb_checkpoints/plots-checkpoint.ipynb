# %%
import sys
sys.path.append('../../') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import fuzzytools.matplotlib.plots as ftplots

n = 100
x = np.random.randint(0, 10, n)
y = np.random.randint(0, 10, n)
unique_names = range(0, 10)
ftplots.plot_hist_labels({'x':x, 'y':y}, unique_names,
    bar_width=0.5,
    title='title!!',
    ylabel='y',
    add_percent=1,
    )
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import fuzzytools.matplotlib.plots as ftplots

bargroup_legends = ['a','b','c','d']
data_dic = {
    'mdl1':{'a':1,'b':2,'c':3,'d':0},
    'mdl2':{'a':1,'b':9,'c':9,'d':0},
    'mdl3':{'a':1,'b':12,'c':9,'d':8},
    'mdl4':{'a':1,'b':12,'c':9,'d':8},
}
plots.plot_bar(data_dic, bargroup_legends,
    title='title!!',
    ylabel='y',
    legend_ncol=5,
    )
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1e760fa2fc72> in <module>
#      11     'mdl4':{'a':1,'b':12,'c':9,'d':8},
#      12 }
# ---> 13 plots.plot_bar(data_dic, bargroup_legends,
#      14     title='title!!',
#      15     ylabel='y',
#
# NameError: name 'plots' is not defined

# %%
# %load_ext autoreload
# %autoreload 2
import flamingChoripan.cutePlots.plots as plots
import numpy as np

data_dic = {
    'x':np.array([1,1,1,2,3,6,4,4,4,4,1,2,3,2,3,4,8]),
    'y':np.array([1,1,1,2,3,6,4,4,4,4,1,2,3,2,3,4,8]),
    'z':np.array([1,1,1,2,3,6,4,4,4,4,1,2,3,2,3,4,8])*2,
}
kwargs = {
    'title':'title!!',
    'ylabel':'y',
    'legend_ncol':5,
    #'xlim':[1,3],
}
plots.plot_hist_discrete(data_dic, bar_width=0.5, **kwargs)

# %%
# %load_ext autoreload
# %autoreload 2
import flamingChoripan.cutePlots.plots as plots
import numpy as np

data_dic = {
    'x':np.array([1,1,1,2,3,6,4,4,4,4,1,2,3,2,3,4,8]),
    'y':np.array([1,1,1,2,3,6,4,4,4,4,1,2,3,2,3,4,8]),
    'z':np.array([1,1,1,2,3,6,4,4,4,4,1,2,3,2,3,4,8])*2,
}
kwargs = {
    'title':'title!!',
    'ylabel':'y',
    'legend_ncol':5,
    #'xlim':[1,3],
}
plots.plot_hist_discrete(data_dic, bar_width=0.5, **kwargs)

# %%
# %load_ext autoreload
# %autoreload 2
import flamingChoripan.cutePlots.cm_plots as cm_plots
import numpy as np

cm = np.random.randint(0, 100, size=(4,4))
classes = ['a','b','c','d']
print(cm)
kwargs = {
    'normalize_mode':None,
    'uses_percent':1,
    'add_accuracy_in_title':1,
}
new_order_classes = ['b','a','d','c']
cm_plots.plot_custom_confusion_matrix(cm, classes, **kwargs)
cm_plots.plot_custom_confusion_matrix(cm, classes, new_order_classes=new_order_classes, **kwargs)

# %%
import numpy as np

y_pred = np.array([0,1,0,2,0])
y_target = np.array([1,2,3,0,0])
classes = ['a','b','c','d']
kwargs = {
    'normalize_mode':None,
    #'normalize_mode':'true',
    'uses_percent':1,
    'add_accuracy_in_title':1,
}
cm_plots.plot_confusion_matrix(y_pred, y_target, classes, **kwargs)

# %%
# %load_ext autoreload
# %autoreload 2
import flamingChoripan.dataScience.metrics as dsm
import numpy as np

y_pred = np.array([0,1,0,2,0])
y_target = np.array([1,2,3,0,0])
kwargs = {
    'y_pred_is_onehot':0,
    'y_target_is_onehot':0,
}
dsm.get_cm_accuracy(y_pred, y_target, **kwargs)

# %%
import matplotlib.pyplot as plt
from fuzzytools.matplotlib.utils import save_fig

fig, ax = plt.subplots(1, 1)

ax.plot([1,5],[8,9])
ax.plot()
save_fig(fig, ['../temp/x.png', '../temp/x2.png', '../temp/x3.png'])
